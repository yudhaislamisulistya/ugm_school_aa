# %%
import pandas as pd 
import numpy as np
from numpy.random import default_rng

# %% [markdown]
# # BUAT DATASET ASSIGMENT PROBLEM
# 1. DATASET NJOB = 10 & NPERSON = 10
# 2. DATASET NJOB = 10 & NPERSON = 20
# 3. DATASET NJOB = 20 & NPERSON = 10
# 4. DATASET NJOB = 20 & NPERSON = 20
# 5. DATASET NJOB = 40 & NPERSON = 40

# %%
rng = default_rng()
def bangkitkan_data(total_data):
    return rng.integers(0, 100, size=total_data)

def buat_dataset(nperson, njob):
    total_data = njob * nperson
    data = bangkitkan_data(total_data)
    data = data.reshape(nperson, njob)
    data = pd.DataFrame(data)
    data.columns = [f'J{i}' for i in range(1, njob+1)]
    data.to_csv(f'dataset_assigment_{nperson}_{njob}.csv', index=False)
    return data

d_10_10 = buat_dataset(10, 10)
d_10_20 = buat_dataset(10, 20)
d_20_10 = buat_dataset(20, 10)
d_20_20 = buat_dataset(20, 20)
d_40_40 = buat_dataset(40, 40)

# %%
d_10_10
# Out:
#    J1  J2  J3  J4  J5  J6  J7  J8  J9  J10
# 0  61  93  99  95  56   6  78  57  67   67
# 1  21  22  33  41  86  13   4  56  39    4
# 2  25  96  96  53  49  55   3  42  45   32
# 3  40  77  87  90  69  46  93  37   1   19
# 4  23  31  31  95  42   1  70  14  12   81
# 5  40  20  46  20  73  24  59  48  44   94
# 6  21  65  73  72   7  48  33  87  69   66
# 7  62  53  53  69  10  14  19  63  78    0
# 8  93  21  83  62  79  99  93  53  73   20
# 9  91  36  63  27  14  52  15   0  20   74

# %%
d_10_20
# Out:
#    J1  J2  J3  J4  J5  J6  J7  J8  J9  J10  J11  J12  J13  J14  J15  J16  J17  \
# 0   1  35  81  97  11  50  95  50   1   67   80   94   65    0   22    7   81
# 1  88  45  84  87  71  34  72  15  18   51   97   36   61   89   62   58   26
# 2   9  90   9   1  39  51  39  39  71   80   96   31   58   34   61   91   35
# 3  13  12  29  62  83  76  92  70  15   62   30   77   12    5   49   38   33
# 4  59  38  22  53  52  49  37  22  13   67   54   82   56   34   11   76   92
# 5  82  67  92  20  93  37  93  21  48    5   67   22   43   35   88   99   65
# 6  28  56  67  27  36  34  18  92  35   74   22   66   70   15   71   34   72
# 7  13  25  43  38  92  24  85  16  65   20   72   88   77   95   98   27   75
# 8  21  23  22  31  39   8   5   6  50   60   37   63   69   88   71   41   81
# 9  92   5  19  78  66  37  67  18  75   58   39   15   74   91   12   25   29
#
#    J18  J19  J20
# 0   43    0   54
# 1   37   25   76
# 2   38   86   97
# 3   43   10   57
# 4   45   97   33
# ...

# %%
d_20_10
# Out:
#     J1  J2  J3  J4  J5  J6  J7  J8  J9  J10
# 0   94  17  22  40  15  62  25  93  77    4
# 1   44  72  58   1  53  85  24   9  13   17
# 2    9  22  19  53  79   7  10  12  35   44
